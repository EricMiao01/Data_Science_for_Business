# %%
import pandas as pd

# %%
excel_name = "03-Neural network.xlsx"
sheet = "Bike_data"
df = pd.read_excel(excel_name, sheet_name = sheet)

# %% [markdown]
# # Viewing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  datetime64[ns]
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(12)
# memory usage: 2.3 MB

# %%
df.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %%
df.head()
# Out:
#    instant     dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1 2011-01-01       1   0     1   0        0        6           0
# 1        2 2011-01-01       1   0     1   1        0        6           0
# 2        3 2011-01-01       1   0     1   2        0        6           0
# 3        4 2011-01-01       1   0     1   3        0        6           0
# 4        5 2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
df.tail()
# Out:
#        instant     dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 17374    17375 2012-12-31       1   1    12  19        0        1           1
# 17375    17376 2012-12-31       1   1    12  20        0        1           1
# 17376    17377 2012-12-31       1   1    12  21        0        1           1
# 17377    17378 2012-12-31       1   1    12  22        0        1           1
# 17378    17379 2012-12-31       1   1    12  23        0        1           1
#
#        weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 17374           2  0.26  0.2576  0.60     0.1642      11         108  119
# 17375           2  0.26  0.2576  0.60     0.1642       8          81   89
# 17376           1  0.26  0.2576  0.60     0.1642       7          83   90
# 17377           1  0.26  0.2727  0.56     0.1343      13          48   61
# 17378           1  0.26  0.2727  0.65     0.1343      12          37   49

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=17379, step=1),
#  Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#         'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#         'casual', 'registered', 'cnt'],
#        dtype='object')]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=17379, step=1)

# %%
df.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
df.sort_index()
# Out:
#        instant     dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0            1 2011-01-01       1   0     1   0        0        6           0
# 1            2 2011-01-01       1   0     1   1        0        6           0
# 2            3 2011-01-01       1   0     1   2        0        6           0
# 3            4 2011-01-01       1   0     1   3        0        6           0
# 4            5 2011-01-01       1   0     1   4        0        6           0
# ...        ...        ...     ...  ..   ...  ..      ...      ...         ...
# 17374    17375 2012-12-31       1   1    12  19        0        1           1
# 17375    17376 2012-12-31       1   1    12  20        0        1           1
# 17376    17377 2012-12-31       1   1    12  21        0        1           1
# 17377    17378 2012-12-31       1   1    12  22        0        1           1
# 17378    17379 2012-12-31       1   1    12  23        0        1           1
#
# ...

# %%
df.sort_values(by = 'temp')
# Out:
#        instant     dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 8721      8722 2012-01-04       1   1     1   5        0        3           1
# 8719      8720 2012-01-04       1   1     1   3        0        3           1
# 8720      8721 2012-01-04       1   1     1   4        0        3           1
# 8722      8723 2012-01-04       1   1     1   6        0        3           1
# 8723      8724 2012-01-04       1   1     1   7        0        3           1
# ...        ...        ...     ...  ..   ...  ..      ...      ...         ...
# 4936      4937 2011-07-29       3   0     7  14        0        5           1
# 4937      4938 2011-07-29       3   0     7  15        0        5           1
# 4938      4939 2011-07-29       3   0     7  16        0        5           1
# 12972    12973 2012-06-29       3   1     6  17        0        5           1
# 13163    13164 2012-07-07       3   1     7  16        0        6           0
#
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Selection

# %%
df["dteday"]
# Out:
# 0       2011-01-01
# 1       2011-01-01
# 2       2011-01-01
# 3       2011-01-01
# 4       2011-01-01
#            ...
# 17374   2012-12-31
# 17375   2012-12-31
# 17376   2012-12-31
# 17377   2012-12-31
# 17378   2012-12-31
# Name: dteday, Length: 17379, dtype: datetime64[ns]

# %%
df[['temp']]
# Out:
#        temp
# 0      0.24
# 1      0.22
# 2      0.22
# 3      0.24
# 4      0.24
# ...     ...
# 17374  0.26
# 17375  0.26
# 17376  0.26
# 17377  0.26
# 17378  0.26
#
# [17379 rows x 1 columns]

# %%
df[0:3]
# Out:
#    instant     dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1 2011-01-01       1   0     1   0        0        6           0
# 1        2 2011-01-01       1   0     1   1        0        6           0
# 2        3 2011-01-01       1   0     1   2        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32

# %%
df[2:3]
# Out:
#    instant     dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 2        3 2011-01-01       1   0     1   2        0        6           0
#
#    weathersit  temp   atemp  hum  windspeed  casual  registered  cnt
# 2           1  0.22  0.2727  0.8        0.0       5          27   32

# %% [markdown]
# ## Selection by label

# %%
df.loc[:10, ["dteday", "temp"]]
# Out:
#        dteday  temp
# 0  2011-01-01  0.24
# 1  2011-01-01  0.22
# 2  2011-01-01  0.22
# 3  2011-01-01  0.24
# 4  2011-01-01  0.24
# 5  2011-01-01  0.24
# 6  2011-01-01  0.22
# 7  2011-01-01  0.20
# 8  2011-01-01  0.24
# 9  2011-01-01  0.32
# 10 2011-01-01  0.38

# %%
df.loc[10, ["dteday", "temp"]]
# Out:
# dteday    2011-01-01 00:00:00
# temp                     0.38
# Name: 10, dtype: object

# %% [markdown]
# ## Selection by position

# %%
df.iloc[3]
# Out:
# instant                         4
# dteday        2011-01-01 00:00:00
# season                          1
# yr                              0
# mnth                            1
# hr                              3
# holiday                         0
# weekday                         6
# workingday                      0
# weathersit                      1
# temp                         0.24
# atemp                      0.2879
# hum                          0.75
# windspeed                     0.0
# casual                          3
# registered                     10
# cnt                            13
# Name: 3, dtype: object

# %%
df.iloc[:10, [1, 10]]
# Out:
#       dteday  temp
# 0 2011-01-01  0.24
# 1 2011-01-01  0.22
# 2 2011-01-01  0.22
# 3 2011-01-01  0.24
# 4 2011-01-01  0.24
# 5 2011-01-01  0.24
# 6 2011-01-01  0.22
# 7 2011-01-01  0.20
# 8 2011-01-01  0.24
# 9 2011-01-01  0.32

# %%
df.iloc[0, 1]
# Out:
# Timestamp('2011-01-01 00:00:00')

# %% [markdown]
# ## Boolean indexing

# %%
df[df["yr"] > 0]
# Out:
#        instant     dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 8645      8646 2012-01-01       1   1     1   0        0        0           0
# 8646      8647 2012-01-01       1   1     1   1        0        0           0
# 8647      8648 2012-01-01       1   1     1   2        0        0           0
# 8648      8649 2012-01-01       1   1     1   3        0        0           0
# 8649      8650 2012-01-01       1   1     1   4        0        0           0
# ...        ...        ...     ...  ..   ...  ..      ...      ...         ...
# 17374    17375 2012-12-31       1   1    12  19        0        1           1
# 17375    17376 2012-12-31       1   1    12  20        0        1           1
# 17376    17377 2012-12-31       1   1    12  21        0        1           1
# 17377    17378 2012-12-31       1   1    12  22        0        1           1
# 17378    17379 2012-12-31       1   1    12  23        0        1           1
#
# ...

# %%
df[df["yr"] < 1]
# Out:
#       instant     dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0           1 2011-01-01       1   0     1   0        0        6           0
# 1           2 2011-01-01       1   0     1   1        0        6           0
# 2           3 2011-01-01       1   0     1   2        0        6           0
# 3           4 2011-01-01       1   0     1   3        0        6           0
# 4           5 2011-01-01       1   0     1   4        0        6           0
# ...       ...        ...     ...  ..   ...  ..      ...      ...         ...
# 8640     8641 2011-12-31       1   0    12  19        0        6           0
# 8641     8642 2011-12-31       1   0    12  20        0        6           0
# 8642     8643 2011-12-31       1   0    12  21        0        6           0
# 8643     8644 2011-12-31       1   0    12  22        0        6           0
# 8644     8645 2011-12-31       1   0    12  23        0        6           0
#
# ...

# %%
df.count()
# Out:
# instant       17379
# dteday        17379
# season        17379
# yr            17379
# mnth          17379
# hr            17379
# holiday       17379
# weekday       17379
# workingday    17379
# weathersit    17379
# temp          17379
# atemp         17379
# hum           17379
# windspeed     17379
# casual        17379
# registered    17379
# cnt           17379
# dtype: int64

# %%
df.mean()
# Out:
# C:\Users\MiaoMiao\AppData\Local\Temp\ipykernel_19588\3698961737.py:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.mean()
# instant       8690.000000
# season           2.501640
# yr               0.502561
# mnth             6.537775
# hr              11.546752
# holiday          0.028770
# weekday          3.003683
# workingday       0.682721
# weathersit       1.425283
# temp             0.496987
# atemp            0.475775
# hum              0.627229
# windspeed        0.190098
# casual          35.676218
# registered     153.786869
# cnt            189.463088
# dtype: float64

# %%
df.median()
# Out:
# C:\Users\MiaoMiao\AppData\Local\Temp\ipykernel_19588\530051474.py:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.median()
# instant       8690.0000
# season           3.0000
# yr               1.0000
# mnth             7.0000
# hr              12.0000
# holiday          0.0000
# weekday          3.0000
# workingday       1.0000
# weathersit       1.0000
# temp             0.5000
# atemp            0.4848
# hum              0.6300
# windspeed        0.1940
# casual          17.0000
# registered     115.0000
# cnt            142.0000
# dtype: float64

# %% [markdown]
# # Working with column

# %%
df.columns.tolist()
# Out:
# ['instant',
#  'dteday',
#  'season',
#  'yr',
#  'mnth',
#  'hr',
#  'holiday',
#  'weekday',
#  'workingday',
#  'weathersit',
#  'temp',
#  'atemp',
#  'hum',
#  'windspeed',
#  'casual',
#  'registered',
#  'cnt']

# %%
df.columns.values
# Out:
# array(['instant', 'dteday', 'season', 'yr', 'mnth', 'hr', 'holiday',
#        'weekday', 'workingday', 'weathersit', 'temp', 'atemp', 'hum',
#        'windspeed', 'casual', 'registered', 'cnt'], dtype=object)

# %%
df.rename(columns={'dteday':'date'})
# Out:
#        instant       date  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0            1 2011-01-01       1   0     1   0        0        6           0
# 1            2 2011-01-01       1   0     1   1        0        6           0
# 2            3 2011-01-01       1   0     1   2        0        6           0
# 3            4 2011-01-01       1   0     1   3        0        6           0
# 4            5 2011-01-01       1   0     1   4        0        6           0
# ...        ...        ...     ...  ..   ...  ..      ...      ...         ...
# 17374    17375 2012-12-31       1   1    12  19        0        1           1
# 17375    17376 2012-12-31       1   1    12  20        0        1           1
# 17376    17377 2012-12-31       1   1    12  21        0        1           1
# 17377    17378 2012-12-31       1   1    12  22        0        1           1
# 17378    17379 2012-12-31       1   1    12  23        0        1           1
#
# ...

# %%
df.drop('casual', axis = 1, inplace = False)
# Out:
#        instant     dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0            1 2011-01-01       1   0     1   0        0        6           0
# 1            2 2011-01-01       1   0     1   1        0        6           0
# 2            3 2011-01-01       1   0     1   2        0        6           0
# 3            4 2011-01-01       1   0     1   3        0        6           0
# 4            5 2011-01-01       1   0     1   4        0        6           0
# ...        ...        ...     ...  ..   ...  ..      ...      ...         ...
# 17374    17375 2012-12-31       1   1    12  19        0        1           1
# 17375    17376 2012-12-31       1   1    12  20        0        1           1
# 17376    17377 2012-12-31       1   1    12  21        0        1           1
# 17377    17378 2012-12-31       1   1    12  22        0        1           1
# 17378    17379 2012-12-31       1   1    12  23        0        1           1
#
# ...

# %%
df
# Out:
#        instant     dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0            1 2011-01-01       1   0     1   0        0        6           0
# 1            2 2011-01-01       1   0     1   1        0        6           0
# 2            3 2011-01-01       1   0     1   2        0        6           0
# 3            4 2011-01-01       1   0     1   3        0        6           0
# 4            5 2011-01-01       1   0     1   4        0        6           0
# ...        ...        ...     ...  ..   ...  ..      ...      ...         ...
# 17374    17375 2012-12-31       1   1    12  19        0        1           1
# 17375    17376 2012-12-31       1   1    12  20        0        1           1
# 17376    17377 2012-12-31       1   1    12  21        0        1           1
# 17377    17378 2012-12-31       1   1    12  22        0        1           1
# 17378    17379 2012-12-31       1   1    12  23        0        1           1
#
# ...

# %%
df['season'].values
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
df['season'].count
# Out:
# <bound method Series.count of 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 17374    1
# 17375    1
# 17376    1
# 17377    1
# 17378    1
# Name: season, Length: 17379, dtype: int64>

# %%
df.columns[1]
# Out:
# 'dteday'

# %%
df.columns[[1, 2, 4]]
# Out:
# Index(['dteday', 'season', 'mnth'], dtype='object')

# %%
df[df.columns[[0, 2]]].describe()
# Out:
#           instant        season
# count  17379.0000  17379.000000
# mean    8690.0000      2.501640
# std     5017.0295      1.106918
# min        1.0000      1.000000
# 25%     4345.5000      2.000000
# 50%     8690.0000      3.000000
# 75%    13034.5000      3.000000
# max    17379.0000      4.000000

# %%
df['season'].isnull
# Out:
# <bound method Series.isnull of 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 17374    1
# 17375    1
# 17376    1
# 17377    1
# 17378    1
# Name: season, Length: 17379, dtype: int64>

# %%
df[df['season'] != 1]
# Out:
#        instant     dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 1807      1808 2011-03-21       2   0     3   0        0        1           1
# 1808      1809 2011-03-21       2   0     3   1        0        1           1
# 1809      1810 2011-03-21       2   0     3   2        0        1           1
# 1810      1811 2011-03-21       2   0     3   3        0        1           1
# 1811      1812 2011-03-21       2   0     3   5        0        1           1
# ...        ...        ...     ...  ..   ...  ..      ...      ...         ...
# 17112    17113 2012-12-20       4   1    12  19        0        4           1
# 17113    17114 2012-12-20       4   1    12  20        0        4           1
# 17114    17115 2012-12-20       4   1    12  21        0        4           1
# 17115    17116 2012-12-20       4   1    12  22        0        4           1
# 17116    17117 2012-12-20       4   1    12  23        0        4           1
#
# ...

# %%
df.instant.nunique()
# Out:
# 17379
